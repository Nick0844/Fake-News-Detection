# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re
import joblib
import string

# %%
fake = pd.read_csv('Fake.csv')
true = pd.read_csv('True.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake['class']=0
true['class']=1

# %%
data = pd.concat([fake,true],axis = 0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 9939   OUCH! BERNIE SANDERS Responds To Hillary’s Cri...
# 10735  DELUSIONAL HILLARY Calls Her Email Scandal The...
# 4760    U.S. Women’s Soccer Star Megan Rapinoe Kneels...
# 22754       SUNDAY SCREENING: Operation Hollywood (2004)
# 14728  Gunmen shoot dead police officer and family in...
# 10008  America’s ‘Hottest’ Conservative Joins Fox New...
# 6079   Standing Rock Sioux tribe opposes Trump order ...
# 10943  Exclusive: Obama to propose $2.5 billion tax c...
# 14707  Peru's Kuczynski denies allegations of Odebrec...
# 10228    Republican lawmakers to join Obama's Cuba visit
#
#                                                     text       subject  \
# 9939   WFB- The former Democratic presidential candid...      politics
# 10735  Hillary Clinton continues on the path to compl...      politics
# 4760   The protest is growing.Most people don t seem ...          News
# 22754  Our weekly documentary film curated by our edi...   Middle-east
# 14728  ISLAMABAD (Reuters) - Gunmen on a motorcycle s...     worldnews
# 10008  Tomi Lahren recently told The Hollywood Report...      politics
# 6079   (Reuters) - The Standing Rock Sioux tribe in a...  politicsNews
# 10943  WASHINGTON (Reuters) - President Barack Obama ...  politicsNews
# 14707  LIMA (Reuters) - Peruvian President Pedro Pabl...     worldnews
# 10228  WASHINGTON (Reuters) - A small group of Republ...  politicsNews
#
#                      date  class
# 9939         Sep 10, 2017      0
# 10735        May 31, 2017      0
# 4760    September 5, 2016      0
# 22754    October 15, 2017      0
# 14728  November 15, 2017       1
# 10008        Aug 30, 2017      0
# 6079    January 24, 2017       1
# 10943   February 5, 2016       1
# 14707  November 15, 2017       1
# 10228     March 18, 2016       1

# %%
data =data.drop(["title","subject","date"],axis = 1)

# %%
data.reset_index(inplace=True)

# %%
data.drop(["index"],axis = 1,inplace=True)

# %%
data.sample(5)
# Out:
#                                                     text  class
# 8076   The enormous debt students incur for college i...      0
# 8827   While the enormous sense of loss the world exp...      0
# 954    This week, Donald Trump joined a collection of...      0
# 41975  DUBAI (Reuters) - Five Bahraini policemen were...      1
# 35067  WASHINGTON (Reuters) - The United States on Th...      1

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]',"",text)
    text = re.sub("\W"," ",text)
    text = re.sub("https?:://\S+|www\.\S+","",text)
    text = re.sub("<.*?>+","",text)
    text = re.sub("[%s]"% re.escape(string.punctuation),"",text)
    text = re.sub("\n","",text)
    text = re.sub("\w*\d\w*","",text)
    return text

# %%
data["text"] = data["text"].astype(str).apply(clean_text)

# %%
x=data["text"]
y=data["class"]

xtrain, xtest, ytrain, ytest = train_test_split( x,y,test_size=0.25,random_state=42)

# %%
vectorizer = TfidfVectorizer()
xv_train = vectorizer.fit_transform(xtrain)
xv_test = vectorizer.transform(xtest)

# %%
lr = LogisticRegression()
lr.fit(xv_train, ytrain)
# Out:
# LogisticRegression()

# %%
prediction = lr.predict(xv_test)
lr.score(xv_test,ytest)
# Out:
# 0.9880623608017818

# %%
print(classification_report(ytest,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5899
#            1       0.99      0.99      0.99      5326
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
joblib.dump(vectorizer,"vectorizer.jb")
joblib.dump(lr,"lr_model.jb")
# Out:
# ['lr_model.jb']
